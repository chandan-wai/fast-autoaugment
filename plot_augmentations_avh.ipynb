# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
hardness_save_path = "/efs-cotton/outputs/fast-autoaugment/confs/hardnessaware/wresnet28x10_rcifar-AA-rerun3/hardness_scores/exp1.pt"

# %%
hardness_scores = torch.load(hardness_save_path)

# %%
num_images = len(hardness_scores['easy_hardness_scores']['unaugmented'])

# %%
plt.figure(figsize=(15,7))
for key, value in hardness_scores['easy_hardness_scores'].items():
    plt.plot(np.arange(50), hardness_scores['easy_hardness_scores'][key][:50])
    plt.scatter(np.arange(50), hardness_scores['easy_hardness_scores'][key][:50])
plt.legend(list(hardness_scores['easy_hardness_scores'].keys()))
plt.show()

# %%
plt.figure(figsize=(15,7))
legend = []
for key, value in hardness_scores['easy_hardness_scores'].items():
    if "Cutout" in key:
        continue
    plt.plot(np.arange(50), hardness_scores['easy_hardness_scores'][key][:50])
    plt.scatter(np.arange(50), hardness_scores['easy_hardness_scores'][key][:50])
    legend.append(key)
plt.legend(legend)
plt.show()

# %%
plt.figure(figsize=(15,7))
legend = []
for key, value in hardness_scores['easy_hardness_scores'].items():
    if "Rotate" in key:
        continue
    plt.plot(np.arange(50), hardness_scores['easy_hardness_scores'][key][:50])
    plt.scatter(np.arange(50), hardness_scores['easy_hardness_scores'][key][:50])
    legend.append(key)
plt.legend(legend)
plt.show()

# %%
plt.figure(figsize=(15,7))
for key, value in hardness_scores['hard_hardness_scores'].items():
    plt.plot(np.arange(num_images), hardness_scores['hard_hardness_scores'][key])
plt.legend(list(hardness_scores['hard_hardness_scores'].keys()))
plt.show()

# %%
plt.figure(figsize=(15,7))
for key, value in hardness_scores['easy_hardness_scores'].items():
    plt.plot(np.arange(num_images), hardness_scores['easy_hardness_scores'][key])

easy = ["easy_" + key for key in list(hardness_scores['easy_hardness_scores'].keys())]

for key, value in hardness_scores['hard_hardness_scores'].items():
    plt.plot(np.arange(num_images), hardness_scores['hard_hardness_scores'][key])
plt.legend(easy + ["hard_" + key for key in list(hardness_scores['hard_hardness_scores'].keys())])

plt.show()

# %%
plt.plot(np.arange(50), unaugmented_easy_hardness_scores, color='green')
plt.plot(np.arange(50), unaugmented_hard_hardness_scores, color='black')

plt.plot(np.arange(50), policy_mean_easy, color='r')
plt.plot(np.arange(50), policy_mean_easy-policy_std_easy, color='b')
plt.plot(np.arange(50), policy_mean_easy+policy_std_easy, color='b')
plt.fill_between(np.arange(50), policy_mean_easy-policy_std_easy, policy_mean_easy+policy_std_easy, color='blue', alpha=0.1)

plt.plot(np.arange(50), policy_mean_hard, color='r')
plt.plot(np.arange(50), policy_mean_hard-policy_std_hard, color='b')
plt.plot(np.arange(50), policy_mean_hard+policy_std_hard, color='b')
plt.fill_between(np.arange(50), policy_mean_hard-policy_std_hard, policy_mean_hard+policy_std_hard, color='blue', alpha=0.1)
plt.ylim(0, 0.2)
plt.xlabel('images')
plt.ylabel('avh_scores')
plt.legend(["unaugmented_easy", "unaugmented_hard", "easy", "", "", "hard", "", ""])
plt.show();

# %%
plt.hist(hardness_scores['hard_hardness_scores']['Rotate90'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['easy_hardness_scores']['Rotate90'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(["Rotate90_hard", "unaugmented_hard", "Rotate90_easy", "unaugmented_easy"])

# %%
plt.hist(hardness_scores['hard_hardness_scores']['Rotate60'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['easy_hardness_scores']['Rotate60'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(["Rotate60_hard", "unaugmented_hard", "Rotate60_easy", "unaugmented_easy"])

# %%
plt.hist(hardness_scores['hard_hardness_scores']['Rotate60'][-50:])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'][-50:])
plt.hist(hardness_scores['easy_hardness_scores']['Rotate60'][:50])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'][:50])
plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(["Rotate60_hard", "unaugmented_hard", "Rotate60_easy", "unaugmented_easy"])

# %%
plt.hist(hardness_scores['hard_hardness_scores']['Rotate30'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['easy_hardness_scores']['Rotate30'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(["Rotate30_hard", "unaugmented_hard", "Rotate30_easy", "unaugmented_easy"])

# %%
# plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['Rotate0'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['easy_hardness_scores']['Rotate0'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
# plt.hist(hardness_scores['easy_hardness_scores']['Rotate30'])
plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(["Rotate0_hard", "unaugmented_hard", "Rotate0_easy", "unaugmented_easy"])

# %%
# plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['Cutout20'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['easy_hardness_scores']['Cutout20'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
# plt.hist(hardness_scores['easy_hardness_scores']['Rotate90'])
plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(["Cutout20_hard", "unaugmented_hard", "Cutout20_easy", "unaugmented_easy"])

# %%
# plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['Cutout15'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['easy_hardness_scores']['Cutout15'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
# plt.hist(hardness_scores['easy_hardness_scores']['Rotate90'])
plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(["Cutout15_hard", "unaugmented_hard", "Cutout15_easy", "unaugmented_easy"])

# %%
# plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['Cutout10'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['easy_hardness_scores']['Cutout10'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
# plt.hist(hardness_scores['easy_hardness_scores']['Rotate90'])
plt.xlabel('absolute AVH')
plt.ylabel('number of images')
plt.legend(["Cutout10_hard", "unaugmented_hard", "Cutout10_easy", "unaugmented_easy"])

# %%
# plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['Cutout5'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['easy_hardness_scores']['Cutout5'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
# plt.hist(hardness_scores['easy_hardness_scores']['Rotate90'])
plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(["Cutout5_hard", "unaugmented_hard", "Cutout5_easy", "unaugmented_easy"])

# %%
plt.hist(hardness_scores['easy_hardness_scores']['Rotate0'])
plt.hist(hardness_scores['easy_hardness_scores']['Rotate30'])
plt.hist(hardness_scores['easy_hardness_scores']['Rotate60'])
plt.hist(hardness_scores['easy_hardness_scores']['Rotate90'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(["Rotate0", "Rotate30", "Rotate60", "Rotate90", "unaugmented_easy", "unaugmented_hard"])

# %%
plt.figure(figsize=(15, 8))
plt.hist(hardness_scores['easy_hardness_scores']['Rotate0'])
plt.hist(hardness_scores['easy_hardness_scores']['Rotate30'])
plt.hist(hardness_scores['easy_hardness_scores']['Rotate60'])
plt.hist(hardness_scores['easy_hardness_scores']['Rotate90'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['Rotate90'])
plt.hist(hardness_scores['hard_hardness_scores']['Rotate60'])
plt.hist(hardness_scores['hard_hardness_scores']['Rotate30'])
plt.hist(hardness_scores['hard_hardness_scores']['Rotate0'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'][:1000], color='purple')

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(["Rotate0_easy", "Rotate30_easy", "Rotate60_easy", "Rotate90_easy", "unaugmented_easy", "Rotate90_hard", "Rotate60_hard", "Rotate30_hard", "Rotate0_hard", "unaugmented_hard", "unaugmented_mid"])

# %%
plt.figure(figsize=(15, 8))
plt.hist(hardness_scores['easy_hardness_scores']['Cutout5'])
plt.hist(hardness_scores['easy_hardness_scores']['Cutout10'])
plt.hist(hardness_scores['easy_hardness_scores']['Cutout15'])
plt.hist(hardness_scores['easy_hardness_scores']['Cutout20'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['Cutout20'])
plt.hist(hardness_scores['hard_hardness_scores']['Cutout15'])
plt.hist(hardness_scores['hard_hardness_scores']['Cutout10'])
plt.hist(hardness_scores['hard_hardness_scores']['Cutout5'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'][:1000], color='purple')

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(["Cutout5_easy", "Cutout10_easy", "Cutout15_easy", "Cutout20_easy", "unaugmented_easy", "Cutout20_hard", "Cutout15_hard", "Cutout10_hard", "Cutout5_hard", "unaugmented_hard", "unaugmented_mid"])

# %%
plt.hist(unaugmented_easy_hardness_scores, bins=50, align='mid')
plt.hist(unaugmented_hard_hardness_scores, bins=50, align='mid')
plt.hist(policy_mean_easy, bins=50, align='mid')
plt.hist(policy_mean_hard, bins=50, align='mid')
plt.hist(policy_std_easy, bins=50, align='mid')
plt.hist(policy_std_hard, bins=50, align='mid')
plt.ylabel('number of images')
plt.xlabel('avh')
plt.legend(["unaugmented_easy", "unaugmented_hard", "augmented_easy", "augmented_hard", "std_easy", "std_hard"])

# %%
hardness_scores2 = torch.load("/efs-cotton/outputs/fast-autoaugment/confs/hardnessaware/wresnet28x10_rcifar-AA-rerun3/hardness_scores/exp2.pt")

# %%
hardness_scores2.keys()
# Out:
# dict_keys(['policy', 'easy_hardness_scores', 'hard_hardness_scores'])

# %%
hardness_scores2['policy']
# Out:
# {'Contrast0': [('Contrast', 1, 0)],
#  'Contrast0.25': [('Contrast', 1, 0.25)],
#  'Contrast0.50': [('Contrast', 1, 0.5)],
#  'Contrast0.75': [('Contrast', 1, 0.75)],
#  'Contrast1': [('Contrast', 1, 1)],
#  'Contrast1.25': [('Contrast', 1, 1.25)],
#  'Contrast1.50': [('Contrast', 1, 1.5)],
#  'Contrast2': [('Contrast', 1, 2)],
#  'Contrast2.5': [('Contrast', 1, 2.5)],
#  'Contrast3': [('Contrast', 1, 3)],
#  'Solarize256': [('Solarize', 1, 256)],
#  'Solarize200': [('Solarize', 1, 200)],
#  'Solarize150': [('Solarize', 1, 150)],
#  'Solarize100': [('Solarize', 1, 100)],
#  'Solarize50': [('Solarize', 1, 50)]}

# %%
hardness_scores2['easy_hardness_scores'].keys()
# Out:
# dict_keys(['unaugmented', 'Contrast0', 'Contrast0.25', 'Contrast0.50', 'Contrast0.75', 'Contrast1', 'Contrast1.25', 'Contrast1.50', 'Contrast2', 'Contrast2.5', 'Contrast3', 'Solarize256', 'Solarize200', 'Solarize150', 'Solarize100', 'Solarize50'])

# %%
len(hardness_scores2['easy_hardness_scores']['Contrast0'])
# Out:
# 200

# %%
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0.25'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0.50'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0.75'])
plt.hist(hardness_scores2['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores2['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Contrast0', 'Contrast0.25', 'Contrast0.50', 'Contrast0.75', "unaugmented_easy", "unaugmented_hard"])

# %%
plt.figure(figsize=(15, 8))
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0.25'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0.50'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0.75'])
plt.hist(hardness_scores2['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores2['hard_hardness_scores']['Contrast0'])
plt.hist(hardness_scores2['hard_hardness_scores']['Contrast0.25'])
plt.hist(hardness_scores2['hard_hardness_scores']['Contrast0.50'])
plt.hist(hardness_scores2['hard_hardness_scores']['Contrast0.75'])
plt.hist(hardness_scores2['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'][:1000], color='purple')

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Contrast0_easy', 'Contrast0.25_easy', 'Contrast0.50_easy', 'Contrast0.75_easy', "unaugmented_easy", 'Contrast0_hard', 'Contrast0.25_hard', 'Contrast0.50_hard', 'Contrast0.75_hard', "unaugmented_hard", "unaugmented_mid"])

# %%
plt.hist(hardness_scores2['easy_hardness_scores']['Solarize50'])
plt.hist(hardness_scores2['easy_hardness_scores']['Solarize100'])
plt.hist(hardness_scores2['easy_hardness_scores']['Solarize150'])
plt.hist(hardness_scores2['easy_hardness_scores']['Solarize200'])
plt.hist(hardness_scores2['easy_hardness_scores']['Solarize256'])
plt.hist(hardness_scores2['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores2['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Solarize50', 'Solarize100', 'Solarize150', 'Solarize200', 'Solarize256', "unaugmented_easy", "unaugmented_hard"])

# %%
plt.figure(figsize=(15, 8))
plt.hist(hardness_scores2['easy_hardness_scores']['Solarize50'])
plt.hist(hardness_scores2['easy_hardness_scores']['Solarize100'])
plt.hist(hardness_scores2['easy_hardness_scores']['Solarize150'])
plt.hist(hardness_scores2['easy_hardness_scores']['Solarize200'])
plt.hist(hardness_scores2['easy_hardness_scores']['Solarize256'])
plt.hist(hardness_scores2['hard_hardness_scores']['Solarize50'])
plt.hist(hardness_scores2['hard_hardness_scores']['Solarize100'])
plt.hist(hardness_scores2['hard_hardness_scores']['Solarize150'])
plt.hist(hardness_scores2['hard_hardness_scores']['Solarize200'])
plt.hist(hardness_scores2['hard_hardness_scores']['Solarize256'])
plt.hist(hardness_scores2['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores2['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'][:1000], color='purple')

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Solarize50', 'Solarize100', 'Solarize150', 'Solarize200', 'Solarize256', 'Solarize50_hard', 'Solarize100_hard', 'Solarize150_hard', 'Solarize200_hard', 'Solarize256_hard', "unaugmented_easy", "unaugmented_hard", "unaugmented_mid"])

# %%
hardness_scores3 = torch.load('/efs-cotton/outputs/fast-autoaugment/confs/hardnessaware/wresnet28x10_rcifar-AA-rerun3/hardness_scores/exp3.pt')

# %%
hardness_scores3['policy']
# Out:
# {'Rotate30+Solarize200': [('Rotate', 1, 30), ('Solarize', 1, 200)],
#  'Rotate30+Solarize100': [('Rotate', 1, 30), ('Solarize', 1, 100)],
#  'Rotate30+Solarize50': [('Rotate', 1, 30), ('Solarize', 1, 50)],
#  'Rotate30+Contrast0.1': [('Rotate', 1, 30), ('Contrast', 1, 0.1)],
#  'Contrast0.1': [('Contrast', 1, 0.1)]}

# %%
hardness_scores3['easy_hardness_scores'].keys()
# Out:
# dict_keys(['unaugmented', 'Rotate30+Solarize200', 'Rotate30+Solarize100', 'Rotate30+Solarize50', 'Rotate30+Contrast0.1', 'Contrast0.1'])

# %%
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0'])
plt.hist(hardness_scores3['easy_hardness_scores']['Contrast0.1'])
plt.hist(hardness_scores3['easy_hardness_scores']['Rotate30+Contrast0.1'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0.25'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0.50'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0.75'])
plt.hist(hardness_scores2['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores2['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Contrast0', 'Contrast0.1', 'Rotate30+Contrast0.1', 'Contrast0.25', 'Contrast0.50', 'Contrast0.75', "unaugmented_easy", "unaugmented_hard"])

# %%
plt.hist(hardness_scores3['easy_hardness_scores']['Rotate30+Solarize50'])
plt.hist(hardness_scores3['easy_hardness_scores']['Rotate30+Solarize100'])
plt.hist(hardness_scores3['easy_hardness_scores']['Rotate30+Solarize200'])
plt.hist(hardness_scores2['easy_hardness_scores']['Solarize200'])
plt.hist(hardness_scores2['easy_hardness_scores']['Solarize256'])
plt.hist(hardness_scores2['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores2['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Rotate30+Solarize50', 'Rotate30+Solarize100', 'Rotate30+Solarize200', 'Solarize200', 'Solarize256', "unaugmented_easy", "unaugmented_hard"])

# %%
hardness_scores2['easy_hardness_scores'].keys()
# Out:
# dict_keys(['unaugmented', 'Contrast0', 'Contrast0.25', 'Contrast0.50', 'Contrast0.75', 'Contrast1', 'Contrast1.25', 'Contrast1.50', 'Contrast2', 'Contrast2.5', 'Contrast3', 'Solarize256', 'Solarize200', 'Solarize150', 'Solarize100', 'Solarize50'])

# %%
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0.25'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0.50'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast0.75'])
plt.hist(hardness_scores2['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores2['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Contrast0', 'Contrast0.25', 'Contrast0.50', 'Contrast0.75', "unaugmented_easy", "unaugmented_hard"])

# %%
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast2'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast1.50'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast1.25'])
plt.hist(hardness_scores2['easy_hardness_scores']['Contrast1'])
plt.hist(hardness_scores2['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores2['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Contrast2', 'Contrast1.50', 'Contrast1.25', 'Contrast1', "unaugmented_easy", "unaugmented_hard"])

# %%
hardness_scores4 = torch.load('/efs-cotton/outputs/fast-autoaugment/confs/hardnessaware/wresnet28x10_rcifar-AA-rerun3/hardness_scores/exp4.pt')

# %%
hardness_scores4['policy'].keys()
# Out:
# dict_keys(['ShearX0.15', 'ShearX0.30', 'ShearX0.60', 'ShearX1', 'ShearX1.5', 'ShearY0.15', 'ShearY0.30', 'ShearY0.60', 'ShearY1', 'ShearY1.5', 'TranslateX5', 'TranslateX10', 'TranslateX15', 'TranslateX20', 'TranslateY5', 'TranslateY10', 'TranslateY15', 'TranslateY20', 'AutoContrast', 'Invert', 'Equalize', 'Flip', 'Posterize0', 'Posterize2', 'Posterize4', 'Posterize6', 'Brightness0', 'Brightness0.05', 'Brightness0.1', 'Brightness0.5', 'Brightness1.5', 'Brightness2', 'Brightness3', 'Color0', 'Color0.05', 'Color0.1', 'Color0.5', 'Color1.5', 'Color2', 'Color3', 'Sharpness0', 'Sharpness0.05', 'Sharpness0.1', 'Sharpness0.5', 'Sharpness1.5', 'Sharpness2', 'Sharpness3'])

# %%
hardness_scores4['easy_hardness_scores'].keys()
# Out:
# dict_keys(['unaugmented', 'ShearX0.15', 'ShearX0.30', 'ShearX0.60', 'ShearX1', 'ShearX1.5', 'ShearY0.15', 'ShearY0.30', 'ShearY0.60', 'ShearY1', 'ShearY1.5', 'TranslateX5', 'TranslateX10', 'TranslateX15', 'TranslateX20', 'TranslateY5', 'TranslateY10', 'TranslateY15', 'TranslateY20', 'AutoContrast', 'Invert', 'Equalize'])

# %%
hardness_scores['policy'].update(hardness_scores2['policy'])

# %%
hardness_scores['policy'].update(hardness_scores3['policy'])
hardness_scores['policy'].update(hardness_scores4['policy'])
hardness_scores['easy_hardness_scores'].update(hardness_scores2['easy_hardness_scores'])
hardness_scores['easy_hardness_scores'].update(hardness_scores3['easy_hardness_scores'])
hardness_scores['easy_hardness_scores'].update(hardness_scores4['easy_hardness_scores'])
hardness_scores['hard_hardness_scores'].update(hardness_scores2['hard_hardness_scores'])
hardness_scores['hard_hardness_scores'].update(hardness_scores3['hard_hardness_scores'])
hardness_scores['hard_hardness_scores'].update(hardness_scores4['hard_hardness_scores'])

# %%
plt.hist(hardness_scores['easy_hardness_scores']['ShearX0.15'])
plt.hist(hardness_scores['easy_hardness_scores']['ShearX0.30'])
plt.hist(hardness_scores['easy_hardness_scores']['ShearX0.60'])
plt.hist(hardness_scores['easy_hardness_scores']['ShearX1'])
plt.hist(hardness_scores['easy_hardness_scores']['ShearX1.5'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['ShearX0.15', 'ShearX0.30', 'ShearX0.60', 'ShearX1', 'ShearX1.5', "unaugmented_easy", "unaugmented_hard"])

# %%
plt.hist(hardness_scores['easy_hardness_scores']['ShearY0.15'])
plt.hist(hardness_scores['easy_hardness_scores']['ShearY0.30'])
plt.hist(hardness_scores['easy_hardness_scores']['ShearY0.60'])
plt.hist(hardness_scores['easy_hardness_scores']['ShearY1'])
plt.hist(hardness_scores['easy_hardness_scores']['ShearY1.5'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['ShearY0.15', 'ShearY0.30', 'ShearY0.60', 'ShearY1', 'ShearY1.5', "unaugmented_easy", "unaugmented_hard"])

# %%
plt.figure(figsize=(15, 8))
plt.hist(hardness_scores['easy_hardness_scores']['ShearX0.15'])
plt.hist(hardness_scores['easy_hardness_scores']['ShearX0.30'])
plt.hist(hardness_scores['easy_hardness_scores']['ShearX0.60'])
plt.hist(hardness_scores['easy_hardness_scores']['ShearX1'])
plt.hist(hardness_scores['easy_hardness_scores']['ShearX1.5'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['ShearX1.5'])
plt.hist(hardness_scores['hard_hardness_scores']['ShearX1'])
plt.hist(hardness_scores['hard_hardness_scores']['ShearX0.60'])
plt.hist(hardness_scores['hard_hardness_scores']['ShearX0.30'])
plt.hist(hardness_scores['hard_hardness_scores']['ShearX0.15'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'][:1000], color='purple')

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['ShearX0.15_easy', 'ShearX0.30_easy', 'ShearX0.60_easy', 'ShearX1_easy', 'ShearX1.5_easy', "unaugmented_easy", 'ShearX1.5_hard', 'ShearX1_hard', 'ShearX0.60_hard', 'ShearX0.30_hard', 'ShearX0.15_hard', "unaugmented_hard", "unaugmented_mid"])

# %%
plt.hist(hardness_scores['easy_hardness_scores']['TranslateX5'])
plt.hist(hardness_scores['easy_hardness_scores']['TranslateX10'])
plt.hist(hardness_scores['easy_hardness_scores']['TranslateX15'])
plt.hist(hardness_scores['easy_hardness_scores']['TranslateX20'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['TranslateX5', 'TranslateX10', 'TranslateX15', 'TranslateX20', "unaugmented_easy", "unaugmented_hard"])

# %%
plt.hist(hardness_scores['easy_hardness_scores']['TranslateY5'])
plt.hist(hardness_scores['easy_hardness_scores']['TranslateY10'])
plt.hist(hardness_scores['easy_hardness_scores']['TranslateY15'])
plt.hist(hardness_scores['easy_hardness_scores']['TranslateY20'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['TranslateY5', 'TranslateY10', 'TranslateY15', 'TranslateY20', "unaugmented_easy", "unaugmented_hard"])

# %%
plt.figure(figsize=(15, 8))
plt.hist(hardness_scores['easy_hardness_scores']['TranslateX5'])
plt.hist(hardness_scores['easy_hardness_scores']['TranslateX10'])
plt.hist(hardness_scores['easy_hardness_scores']['TranslateX15'])
plt.hist(hardness_scores['easy_hardness_scores']['TranslateX20'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['TranslateX20'])
plt.hist(hardness_scores['hard_hardness_scores']['TranslateX15'])
plt.hist(hardness_scores['hard_hardness_scores']['TranslateX10'])
plt.hist(hardness_scores['hard_hardness_scores']['TranslateX5'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'][:1000], color='purple')

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['TranslateX5_easy', 'TranslateX10_easy', 'TranslateX15_easy', 'TranslateX20_easy', "unaugmented_easy", 'TranslateX20_hard', 'TranslateX15_hard', 'TranslateX10_hard', 'TranslateX5_hard', "unaugmented_hard", "unaugmented_mid"])

# %%
plt.figure(figsize=(15, 8))
plt.hist(hardness_scores['easy_hardness_scores']['AutoContrast'])
plt.hist(hardness_scores['easy_hardness_scores']['Invert'])
plt.hist(hardness_scores['easy_hardness_scores']['Equalize'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['AutoContrast'])
plt.hist(hardness_scores['hard_hardness_scores']['Invert'])
plt.hist(hardness_scores['hard_hardness_scores']['Equalize'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'][:1000], color='purple')

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['AutoContrast_easy', 'Invert_easy', 'Equalize_easy', "unaugmented_easy", 'AutoContrast_hard', 'Invert_hard', 'Equalize_hard', "unaugmented_hard", "unaugmented_mid"])

# %%
hardness_scores5 = torch.load('/efs-cotton/outputs/fast-autoaugment/confs/hardnessaware/wresnet28x10_rcifar-AA-rerun3/hardness_scores/exp5.pt')

# %%
hardness_scores['policy'].update(hardness_scores5['policy'])
hardness_scores['easy_hardness_scores'].update(hardness_scores5['easy_hardness_scores'])
hardness_scores['hard_hardness_scores'].update(hardness_scores5['hard_hardness_scores'])

# %%
hardness_scores5['policy'].keys()
# Out:
# dict_keys(['Posterize0', 'Posterize2', 'Posterize4', 'Posterize6', 'Brightness0', 'Brightness0.05', 'Brightness0.1', 'Brightness0.5', 'Brightness1.5', 'Brightness2', 'Brightness3', 'Color0', 'Color0.05', 'Color0.1', 'Color0.5', 'Color1.5', 'Color2', 'Color3', 'Sharpness0', 'Sharpness0.05', 'Sharpness0.1', 'Sharpness0.5', 'Sharpness1.5', 'Sharpness2', 'Sharpness3', 'Flip'])

# %%
plt.hist(hardness_scores['easy_hardness_scores']['Posterize0'])
plt.hist(hardness_scores['easy_hardness_scores']['Posterize2'])
plt.hist(hardness_scores['easy_hardness_scores']['Posterize4'])
plt.hist(hardness_scores['easy_hardness_scores']['Posterize6'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'], color='purple')

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Posterize0', 'Posterize2', 'Posterize4', 'Posterize6', "unaugmented_easy", "unaugmented_hard", "unaugmented_mid"])

# %%
plt.figure(figsize=(15, 8))
plt.hist(hardness_scores['easy_hardness_scores']['Posterize0'])
plt.hist(hardness_scores['easy_hardness_scores']['Posterize2'])
plt.hist(hardness_scores['easy_hardness_scores']['Posterize4'])
plt.hist(hardness_scores['easy_hardness_scores']['Posterize6'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['Posterize0'])
plt.hist(hardness_scores['hard_hardness_scores']['Posterize2'])
plt.hist(hardness_scores['hard_hardness_scores']['Posterize4'])
plt.hist(hardness_scores['hard_hardness_scores']['Posterize6'])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'], color='purple')

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Posterize0_easy', 'Posterize2_easy', 'Posterize4_easy', 'Posterize6_easy', "unaugmented_easy", 'Posterize0_hard', 'Posterize2_hard', 'Posterize4_hard', 'Posterize6_hard', "unaugmented_hard", "unaugmented_mid"])

# %%
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'], range=(0.04, 0.12))
# Out:
# (array([  0.,   0., 200.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#  array([0.04 , 0.048, 0.056, 0.064, 0.072, 0.08 , 0.088, 0.096, 0.104,
#         0.112, 0.12 ], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(hardness_scores['easy_hardness_scores']['Brightness0'])
plt.hist(hardness_scores['easy_hardness_scores']['Brightness0.05'])
plt.hist(hardness_scores['easy_hardness_scores']['Brightness0.1'])
plt.hist(hardness_scores['easy_hardness_scores']['Brightness0.5'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'], color='purple')
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Brightness0', 'Brightness0.05', 'Brightness0.1', 'Brightness0.5', "unaugmented_easy", "unaugmented_mid", "unaugmented_hard"])

# %%
plt.hist(hardness_scores['easy_hardness_scores']['Brightness0'])
plt.hist(hardness_scores['easy_hardness_scores']['Brightness0.05'])
plt.hist(hardness_scores['easy_hardness_scores']['Brightness0.1'])
plt.hist(hardness_scores['easy_hardness_scores']['Brightness0.5'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores['hard_hardness_scores']['Brightness0'])
plt.hist(hardness_scores['hard_hardness_scores']['Brightness0.05'])
plt.hist(hardness_scores['hard_hardness_scores']['Brightness0.1'])
plt.hist(hardness_scores['hard_hardness_scores']['Brightness0.5'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'][:1000], color='purple')
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Brightness0_easy', 'Brightness0.05_Easy', 'Brightness0.1_easy', 'Brightness0.5_easy', "unaugmented_easy", 'Brightness0_hard', 'Brightness0.05_hard', 'Brightness0.1_hard', 'Brightness0.5_hard', "unaugmented_mid", "unaugmented_hard"])

# %%
plt.hist(hardness_scores['easy_hardness_scores']['Brightness3'])
plt.hist(hardness_scores['easy_hardness_scores']['Brightness2'])
plt.hist(hardness_scores['easy_hardness_scores']['Brightness1.5'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'], color='purple')
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Brightness3', 'Brightness2', 'Brightness1.5', "unaugmented_easy", 'unaugmented_mid', "unaugmented_hard"])

# %%
plt.hist(hardness_scores['easy_hardness_scores']['Color0'])
plt.hist(hardness_scores['easy_hardness_scores']['Color0.05'])
plt.hist(hardness_scores['easy_hardness_scores']['Color0.1'])
plt.hist(hardness_scores['easy_hardness_scores']['Color0.5'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'], color='purple')
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Color0', 'Color0.05', 'Color0.1', 'Color0.5', "unaugmented_easy", "unaugmented_mid", "unaugmented_hard"])

# %%
plt.hist(hardness_scores['easy_hardness_scores']['Sharpness0'])
plt.hist(hardness_scores['easy_hardness_scores']['Sharpness0.05'])
plt.hist(hardness_scores['easy_hardness_scores']['Sharpness0.1'])
plt.hist(hardness_scores['easy_hardness_scores']['Sharpness0.5'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'], color='purple')
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Sharpness0', 'Sharpness0.05', 'Sharpness0.1', 'Sharpness0.5', "unaugmented_easy", "unaugmented_mid", "unaugmented_hard"])

# %%
plt.hist(hardness_scores['easy_hardness_scores']['Color3'])
plt.hist(hardness_scores['easy_hardness_scores']['Color2'])
plt.hist(hardness_scores['easy_hardness_scores']['Color1.5'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'], color='purple')
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Color3', 'Color2', 'Color1.5', "unaugmented_easy", 'unaugmented_mid', "unaugmented_hard"])

# %%
plt.hist(hardness_scores['easy_hardness_scores']['Sharpness3'])
plt.hist(hardness_scores['easy_hardness_scores']['Sharpness2'])
plt.hist(hardness_scores['easy_hardness_scores']['Sharpness1.5'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'], color='purple')
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Sharpness3', 'Sharpness2', 'Sharpness1.5', "unaugmented_easy", 'unaugmented_mid', "unaugmented_hard"])

# %%
plt.hist(hardness_scores['easy_hardness_scores']['Brightness0'])
plt.hist(hardness_scores['easy_hardness_scores']['Brightness0.05'])
plt.hist(hardness_scores['easy_hardness_scores']['Brightness0.1'])
plt.hist(hardness_scores['easy_hardness_scores']['Brightness0.5'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['Brightness0'][900:1100])
plt.hist(hardness_scores5['mid_hardness_scores']['Brightness0.05'][900:1100])
plt.hist(hardness_scores5['mid_hardness_scores']['Brightness0.1'][900:1100])
plt.hist(hardness_scores5['mid_hardness_scores']['Brightness0.5'][900:1100])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'], color='purple')
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Brightness0', 'Brightness0.05', 'Brightness0.1', 'Brightness0.5', "unaugmented_easy", 'Brightness0_mid', 'Brightness0.05_mid', 'Brightness0.1_mid', 'Brightness0.5_mid', "unaugmented_mid", "unaugmented_hard"])

# %%
plt.figure(figsize=(15, 8))
plt.hist(hardness_scores['easy_hardness_scores']['Posterize0'])
plt.hist(hardness_scores['easy_hardness_scores']['Posterize2'])
plt.hist(hardness_scores['easy_hardness_scores']['Posterize4'])
plt.hist(hardness_scores['easy_hardness_scores']['Posterize6'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['Brightness0'][900:1100])
plt.hist(hardness_scores5['mid_hardness_scores']['Brightness0.05'][900:1100])
plt.hist(hardness_scores5['mid_hardness_scores']['Brightness0.1'][900:1100])
plt.hist(hardness_scores5['mid_hardness_scores']['Brightness0.5'][900:1100])
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'], color='purple')

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Posterize0', 'Posterize2', 'Posterize4', 'Posterize6', "unaugmented_easy", 'Posterize0_mid', 'Posterize2_mid', 'Posterize4_mid', 'Posterize6_mid', "unaugmented_hard", "unaugmented_mid"])

# %%
hardness_scores6 = torch.load('/efs-cotton/outputs/fast-autoaugment/confs/hardnessaware/wresnet28x10_rcifar-AA-rerun3/hardness_scores/exp6.pt')

# %%
hardness_scores6.keys()
# Out:
# dict_keys(['policy', 'hardness_scores', 'easy_indices', 'mid_indices', 'hard_indices'])

# %%
easy_indices = hardness_scores6['easy_indices']
mid_indices = hardness_scores6['mid_indices']
hard_indices = hardness_scores6['hard_indices']

# %%
hardness_scores6['policy']
# Out:
# {'Sharpness0': [('Sharpness', 1, 0)],
#  'Sharpness-1': [('Sharpness', 1, -1)],
#  'Sharpness-2': [('Sharpness', 1, -2)],
#  'Sharpness-3': [('Sharpness', 1, -3)],
#  'Sharpness4': [('Sharpness', 1, 4)],
#  'Sharpness5': [('Sharpness', 1, 5)],
#  'Sharpness-4': [('Sharpness', 1, -4)]}

# %%
hardness_scores6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-172-d131ee1e394f> in <module>
# ----> 1 hardness_scores6[hardness_scores6['easy_indices']]
#
# TypeError: unhashable type: 'list'

# %%
hardness_scores6['hardness_scores'].keys()
# Out:
# dict_keys(['unaugmented', 'Sharpness0', 'Sharpness-1', 'Sharpness-2', 'Sharpness-3', 'Sharpness4', 'Sharpness5', 'Sharpness-4'])

# %%
plt.hist(hardness_scores6['hardness_scores']['Sharpness5'][easy_indices])
plt.hist(hardness_scores6['hardness_scores']['Sharpness4'][easy_indices])
plt.hist(hardness_scores['easy_hardness_scores']['Sharpness3'])
plt.hist(hardness_scores['easy_hardness_scores']['Sharpness2'])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'], color='purple')
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Sharpness5', 'Sharpness4', 'Sharpness3', 'Sharpness2', "unaugmented_easy", 'unaugmented_mid', "unaugmented_hard"])

# %%
plt.hist(hardness_scores6['hardness_scores']['Sharpness-4'][easy_indices])
plt.hist(hardness_scores6['hardness_scores']['Sharpness-3'][easy_indices])
plt.hist(hardness_scores6['hardness_scores']['Sharpness-2'][easy_indices])
plt.hist(hardness_scores6['hardness_scores']['Sharpness-1'][easy_indices])
plt.hist(hardness_scores6['hardness_scores']['Sharpness0'][easy_indices])
plt.hist(hardness_scores['easy_hardness_scores']['unaugmented'])
plt.hist(hardness_scores5['mid_hardness_scores']['unaugmented'], color='purple')
plt.hist(hardness_scores['hard_hardness_scores']['unaugmented'])

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Sharpness-4', 'Sharpness-3', 'Sharpness-2', 'Sharpness-1', 'Sharpness0', "unaugmented_easy", 'unaugmented_mid', "unaugmented_hard"])

# %%
plt.hist(hardness_scores6['hardness_scores']['Sharpness-4'], alpha=0.5)

plt.hist(hardness_scores6['hardness_scores']['unaugmented'], alpha=0.5)

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Sharpness-4', 'Unaugmented'])

# %%
plt.hist(hardness_scores6['hardness_scores']['Sharpness5'], alpha=0.5)

plt.hist(hardness_scores6['hardness_scores']['unaugmented'], alpha=0.5)

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Sharpness5', 'Unaugmented'])

# %%
hardness_scores7 = torch.load('/efs-cotton/outputs/fast-autoaugment/confs/hardnessaware/wresnet28x10_rcifar-AA-rerun3/hardness_scores/exp7.pt')

# %%
hardness_scores7.keys()
# Out:
# dict_keys(['policy', 'hardness_scores', 'easy_indices', 'mid_indices', 'hard_indices'])

# %%
plt.hist(hardness_scores7['hardness_scores']['unaugmented'])
plt.xlabel('absoluteAVH')
plt.ylabel('number of images')
# Out:
# Text(0, 0.5, 'number of images')

# %%
hardness_scores7['policy'].keys()
# Out:
# dict_keys(['Rotate30', 'Rotate60', 'Rotate90', 'Solarize0', 'Posterize0', 'Cutout20', 'Contrast0', 'Brightness0'])

# %%
hardness_scores7['mid_indices'] == mid_indices
# Out:
# True

# %%
plt.hist(hardness_scores7['hardness_scores']['Rotate90'], alpha=0.5)

plt.hist(hardness_scores7['hardness_scores']['unaugmented'], alpha=0.5)

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Rotate90', 'Unaugmented'])

# %%
plt.hist(hardness_scores7['hardness_scores']['Solarize0'], alpha=0.5)

plt.hist(hardness_scores7['hardness_scores']['unaugmented'], alpha=0.5)

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Solarize0', 'Unaugmented'])

# %%
plt.hist(hardness_scores7['hardness_scores']['Posterize0'], alpha=0.5)

plt.hist(hardness_scores7['hardness_scores']['unaugmented'], alpha=0.5)

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Posterize0', 'Unaugmented'])

# %%
plt.hist(hardness_scores7['hardness_scores']['Cutout20'], alpha=0.5)

plt.hist(hardness_scores7['hardness_scores']['unaugmented'], alpha=0.5)

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Cutout20', 'Unaugmented'])

# %%
plt.hist(hardness_scores7['hardness_scores']['Contrast0'], alpha=0.5)

plt.hist(hardness_scores7['hardness_scores']['unaugmented'], alpha=0.5)

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Contrast0', 'Unaugmented'])

# %%
plt.hist(hardness_scores7['hardness_scores']['Brightness0'], alpha=0.5)

plt.hist(hardness_scores7['hardness_scores']['unaugmented'], alpha=0.5)

plt.xlabel('absolute AVH')
plt.ylabel('numner of images')
plt.legend(['Brightness0', 'Unaugmented'])
